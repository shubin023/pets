# %% [markdown]
# ## Описание

# %% [markdown]
# Information on more than 180,000 Terrorist Attacks<br>
# <br>
# The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland.

# %% [markdown]
# ## Задачи
# <ol>
# <li>Рассмотреть ежегодную статистику количества террористических атак во всём мире.</li>
# <li>Рассмотреть ежегодную статистику количества террористических атак в России.</li>
# <li>Cheese</li>
# </ol>

# %% [markdown]
# ## Загрузка данных

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set(          # настройка размера графика в Jupyter
    font_scale=1,
    style="whitegrid",
    rc={'figure.figsize':(10,10)}
        )

# %%
path_to_file = '/home/anton23/projects/pet_projects/pets/Global_Terrorism_Database/globalterrorismdb_0718dist.csv'  # путь к файлу

# %%
df_terrorism = pd.read_csv(path_to_file, encoding='ISO-8859-1')
# Out:
# /tmp/ipykernel_4143/1235976570.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_terrorism = pd.read_csv(path_to_file, encoding='ISO-8859-1')

# %%
pd.set_option('display.max_columns', None)

# %%
df_terrorism.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region                   region_txt provstate  \
# 0  Dominican Republic       2  Central America & Caribbean       NaN
# 1              Mexico       1                North America   Federal
# 2         Philippines       5               Southeast Asia    Tarlac
# 3              Greece       8               Western Europe    Attica
# 4               Japan       4                    East Asia   Fukouka
#
#             city   latitude   longitude  specificity  vicinity location  \
# ...

# %%
df_terrorism.shape
# Out:
# (181691, 135)

# %%
df_terrorism.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %%
df_terrorism_date_and_location = df_terrorism[['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'region', 'region_txt', 
                                      'country', 'country_txt', 'provstate', 'city', 'vicinity']]

# %%
df_terrorism_date_and_location.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  region  \
# 0  197000000001   1970       7     2        NaN       2
# 1  197000000002   1970       0     0        NaN       1
# 2  197001000001   1970       1     0        NaN       5
# 3  197001000002   1970       1     0        NaN       8
# 4  197001000003   1970       1     0        NaN       4
#
#                     region_txt  country         country_txt provstate  \
# 0  Central America & Caribbean       58  Dominican Republic       NaN
# 1                North America      130              Mexico   Federal
# 2               Southeast Asia      160         Philippines    Tarlac
# 3               Western Europe       78              Greece    Attica
# 4                    East Asia      101               Japan   Fukouka
#
#             city  vicinity
# 0  Santo Domingo         0
# 1    Mexico city         0
# 2        Unknown         0
# 3         Athens         0
# 4        Fukouka         0

# %%
df_terrorism_date_and_location.shape
# Out:
# (181691, 12)

# %%
df_terrorism_date_and_location.dtypes
# Out:
# eventid         int64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
# region          int64
# region_txt     object
# country         int64
# country_txt    object
# provstate      object
# city           object
# vicinity        int64
# dtype: object

# %%
df_terrorism_date_and_location.isna().sum()
# Out:
# eventid             0
# iyear               0
# imonth              0
# iday                0
# approxdate     172452
# region              0
# region_txt          0
# country             0
# country_txt         0
# provstate         421
# city              435
# vicinity            0
# dtype: int64

# %%
year_over_year_global = (df_terrorism_date_and_location
                         .groupby('iyear', as_index=False)
                         .agg({"eventid": 'count'})
                         .rename(columns={'iyear': 'year', 'eventid': 'number'}))

# %%
year_over_year_global
# Out:
#     year  number
# 0   1970     651
# 1   1971     471
# 2   1972     568
# 3   1973     473
# 4   1974     581
# 5   1975     740
# 6   1976     923
# 7   1977    1319
# 8   1978    1526
# 9   1979    2662
# 10  1980    2662
# 11  1981    2586
# 12  1982    2544
# 13  1983    2870
# 14  1984    3495
# 15  1985    2915
# 16  1986    2860
# 17  1987    3183
# 18  1988    3721
# 19  1989    4324
# 20  1990    3887
# 21  1991    4683
# 22  1992    5071
# 23  1994    3456
# 24  1995    3081
# 25  1996    3058
# 26  1997    3197
# 27  1998     934
# 28  1999    1395
# 29  2000    1814
# 30  2001    1906
# 31  2002    1333
# 32  2003    1278
# 33  2004    1166
# 34  2005    2017
# 35  2006    2758
# 36  2007    3242
# 37  2008    4805
# 38  2009    4721
# 39  2010    4826
# 40  2011    5076
# 41  2012    8522
# 42  2013   12036
# 43  2014   16903
# 44  2015   14965
# 45  2016   13587
# 46  2017   10900

# %%
figure = sns.barplot(data=year_over_year_global, x='year', y='number')

figure.set_xlabel('\nYear')                     # Label of x axis
figure.set_ylabel('The number of accidents\n')  # Label of y axis
plt.title("The annual number of terrorist attacks in the world")
plt.xticks(rotation=90)
plt.yticks(range(0, 18000, 1000))
sns.despine()

# %% [markdown]
# Видим, что с 1970 по 1992 наблюдался ежегодный рост количества террористических атак в мире. Макслимальное значение за тот период составляет примеро 5000 атак (1992 год). В период 1992-2004 количество атак падает и колеблется в районе 1200. С 2004 по 2014 случился резкий рост, максимальное значение (2014 год) почти составляет 17000. С 2014 по 2017 наблюдается падение до 11000 (2017 год).

# %% [markdown]
# <b>Рассмотрим отдельно статистику в России </b>

# %% [markdown]
# Рассмотрим отдельно страну Россия. Учитываем также годы в составе СССР.

# %%
year_over_year_Russia = df_terrorism_date_and_location.query("country == 167 | (country == 359 & provstate == 'Russia')")

# %%
year_over_year_Russia.head()
# Out:
#             eventid  iyear  imonth  iday approxdate  region      region_txt  \
# 5768   197801080003   1978       1     8        NaN       9  Eastern Europe
# 38018  198904200003   1989       4    20        NaN       9  Eastern Europe
# 38019  198904200004   1989       4    20        NaN       9  Eastern Europe
# 42316  199004280012   1990       4    28        NaN       9  Eastern Europe
# 42908  199006090018   1990       6     9        NaN       9  Eastern Europe
#
#        country   country_txt provstate     city  vicinity
# 5768       359  Soviet Union    Russia   Moscow         0
# 38018      359  Soviet Union    Russia   Moscow         0
# 38019      359  Soviet Union    Russia   Moscow         0
# 42316      359  Soviet Union    Russia   Moscow         0
# 42908      359  Soviet Union    Russia  Kara-Su         0

# %%
year_over_year_Russia.shape
# Out:
# (2209, 12)

# %%
print(f"C {year_over_year_Russia.query('country == 359').iyear.min()} по {year_over_year_Russia.query('country == 359').iyear.max()} Россия ещё в составе СССР")
# Out:
# C 1978 по 1991 Россия ещё в составе СССР

# %%
print(f"В {year_over_year_Russia.query('country == 167').iyear.min()} первый случай террористической атаки в России как отдельной стране")
# Out:
# В 1992 первый случай террористической атаки в России как отдельной стране

# %%
year_over_year_Russsia = (year_over_year_Russia
                         .groupby('iyear', as_index=False)
                         .agg({"eventid": 'count'})
                         .rename(columns={'iyear': 'year', 'eventid': 'number'}))

# %%
year_over_year_Russsia
# Out:
#     year  number
# 0   1978       1
# 1   1989       2
# 2   1990       6
# 3   1991       6
# 4   1992      21
# 5   1994      47
# 6   1995      37
# 7   1996      66
# 8   1997      77
# 9   1998      26
# 10  1999      54
# 11  2000     138
# 12  2001     135
# 13  2002      89
# 14  2003      76
# 15  2004      44
# 16  2005      64
# 17  2006      56
# 18  2007      51
# 19  2008     170
# 20  2009     152
# 21  2010     251
# 22  2011     188
# 23  2012     151
# 24  2013     144
# 25  2014      48
# 26  2015      21
# 27  2016      55
# 28  2017      33

# %%
figure = sns.barplot(data=year_over_year_Russsia, x='year', y='number')

figure.set_xlabel('\nYear')                     # Label of x axis
figure.set_ylabel('The number of accidents\n')  # Label of y axis
plt.title("The annual number of terrorist attacks in Russia")
plt.xticks(rotation=90)
plt.yticks(range(0, 260, 10))
sns.despine()

# %% [markdown]
# В период 1978-1991, когда Россия была в составе СССР, количество терактов было минимальным и не превышало 6 случаев в год. В период с 1992-2001 (Россия как обособленная страна) наблюдается резкий рост количества террористических атак, максимальное значение - 138 терактов в 2000 году. С 2001 по 2007 количество атак снижалось (минимум 44 в 2004 году). 2007-2010 - резкий рост, в 2010 году был 251 теракт (максимум за всю историю Росси с 1978 по 2017). С 2011 по 2017 количество снизилось (в 2015 - 21 случай).
